# %% [markdown]
# <a href="https://colab.research.google.com/github/SiracencoSerghei/Statistics_and_ML/blob/main/visualization/stats_visualizing_boxWhisker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SECTION: Visualizing data
# ### VIDEO: Box-and-whisker plots

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
## create data for the bar plot

# data sizes
m = 30 # rows
n =  6 # columns

# generate data
data = np.zeros((m,n))

for i in range(n):
    data[:,i] = 30*np.random.randn(m) * (2*i/(n-1)-1)**2 + (i+1)**2

# %%
# now for the boxplot

# plt.boxplot(data)
plt.boxplot(data.T)
plt.show()

# %%
# now with seaborn
sns.boxplot(data=data,orient='v')
plt.show()

# %%
# or as a pandas data frame
df = pd.DataFrame(data,columns=['zero','one','two','three','four','five'])
sns.boxplot(data=df,orient='h')
plt.show()

# %%
# Generate some random data
np.random.seed(42)
data = np.random.normal(100, 20, 200)

# Create the box-and-whiskers plot
fig, ax = plt.subplots()

# Create the boxplot
box = ax.boxplot(data, patch_artist=True, notch=True, flierprops=dict(markerfacecolor='r', marker='o'))

# Annotate the boxplot
for i in range(len(data)):
    if data[i] < np.percentile(data, 25) - 1.5 * (np.percentile(data, 75) - np.percentile(data, 25)) or \
       data[i] > np.percentile(data, 75) + 1.5 * (np.percentile(data, 75) - np.percentile(data, 25)):
        ax.annotate(f'Outlier: {data[i]:.1f}', xy=(1, data[i]), xytext=(1.1, data[i]),
                    arrowprops=dict(facecolor='red', shrink=0.05))

# Customize colors for the box
for element in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
    plt.setp(box[element], color='black')

# Set colors for different parts of the boxplot
colors = ['skyblue']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Annotate the median, quartiles, min, and max
median = np.median(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
whisker_min = np.min(data[data >= q1 - 1.5 * (q3 - q1)])
whisker_max = np.max(data[data <= q3 + 1.5 * (q3 - q1)])

ax.annotate(f'Median: {median:.1f}', xy=(1, median), xytext=(1.05, median + 5),
            arrowprops=dict(facecolor='blue', shrink=0.05))

ax.annotate(f'Q1: {q1:.1f}', xy=(1, q1), xytext=(1.05, q1 - 10),
            arrowprops=dict(facecolor='green', shrink=0.05))

ax.annotate(f'Q3: {q3:.1f}', xy=(1, q3), xytext=(1.05, q3 + 5),
            arrowprops=dict(facecolor='green', shrink=0.05))

ax.annotate(f'Min: {whisker_min:.1f}', xy=(1, whisker_min), xytext=(1.05, whisker_min +5),
            arrowprops=dict(facecolor='purple', shrink=0.05))

ax.annotate(f'Max: {whisker_max:.1f}', xy=(1, whisker_max), xytext=(1.05, whisker_max -10),
            arrowprops=dict(facecolor='purple', shrink=0.05))

# Add labels
ax.set_title('Box-and-Whiskers Plot with Annotations')
ax.set_ylabel('Value')

# Show the plot
plt.show()

# %% [markdown]
# ---
# # Code challenge: Boxplots of normal and uniform noise
# ---

# %%
N = 10
data_normal = np.random.randn(N)
data_uniform = np.random.rand(N)

print(np.round(data_normal,3)), print(' ')
print(np.round(data_uniform,3)), print(' ')

# plotting
sns.boxplot(data=[data_normal, data_uniform], orient='v')

# Overlay the data points
sns.stripplot(data=[data_normal, data_uniform], orient='v', color='black', alpha=0.5, jitter=True)

plt.show()
# Out:
# [ 0.459 -1.1    0.939 -0.671 -0.161  1.372  0.496 -1.079 -1.015 -0.599]
#
# [0.813 0.845 0.259 0.326 0.236 0.908 0.503 0.656 0.415 0.631]
